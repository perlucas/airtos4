# %%
# !sudo apt-get update
# !sudo apt-get install -y xvfb ffmpeg freeglut3-dev

# !pip install tensorflow --upgrade
# !pip install scikit-image --upgrade
#!pip install 'imageio==2.4.0'
#!pip install pyvirtualdisplay
# !pip install tf-agents
# !pip install pyglet xvfbwrapper
# !pip install tf-keras
# !pip install keras-tuner
# !pip install pandas pandas-ta numpy
# Out:
# Get:1 http://ports.ubuntu.com/ubuntu-ports jammy InRelease [270 kB]
# Get:2 http://ports.ubuntu.com/ubuntu-ports jammy-updates InRelease [128 kB]
# Get:3 http://ports.ubuntu.com/ubuntu-ports jammy-backports InRelease [127 kB]
# Get:4 http://ports.ubuntu.com/ubuntu-ports jammy-security InRelease [129 kB]
# Get:5 http://ports.ubuntu.com/ubuntu-ports jammy/multiverse arm64 Packages [224 kB]
# Get:6 http://ports.ubuntu.com/ubuntu-ports jammy/main arm64 Packages [1,758 kB]
# Get:7 http://ports.ubuntu.com/ubuntu-ports jammy/restricted arm64 Packages [24.2 kB]
# Get:8 http://ports.ubuntu.com/ubuntu-ports jammy/universe arm64 Packages [17.2 MB]
# Get:9 http://ports.ubuntu.com/ubuntu-ports jammy-updates/universe arm64 Packages [1,379 kB]
# Get:10 http://ports.ubuntu.com/ubuntu-ports jammy-updates/restricted arm64 Packages [2,400 kB]
# Get:11 http://ports.ubuntu.com/ubuntu-ports jammy-updates/main arm64 Packages [2,217 kB]
# Get:12 http://ports.ubuntu.com/ubuntu-ports jammy-updates/multiverse arm64 Packages [29.5 kB]
# Get:13 http://ports.ubuntu.com/ubuntu-ports jammy-backports/main arm64 Packages [81.0 kB]
# Get:14 http://ports.ubuntu.com/ubuntu-ports jammy-backports/universe arm64 Packages [31.8 kB]
# Get:15 http://ports.ubuntu.com/ubuntu-ports jammy-security/multiverse arm64 Packages [24.1 kB]
# Get:16 http://ports.ubuntu.com/ubuntu-ports jammy-security/main arm64 Packages [1,910 kB]
# Get:17 http://ports.ubuntu.com/ubuntu-ports jammy-security/universe arm64 Packages [1,092 kB]
# Get:18 http://ports.ubuntu.com/ubuntu-ports jammy-security/restricted arm64 Packages [2,286 kB]
# Fetched 31.3 MB in 19s (1,646 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# The following additional packages will be installed:
#   freeglut3 libegl-dev libegl-mesa0 libegl1 libfontenc1 libgbm1 libgl-dev
#   libgl1-mesa-dev libgl1-mesa-dri libglapi-mesa libgles-dev libgles1 libgles2
#   libglu1-mesa libglu1-mesa-dev libglvnd-core-dev libglvnd-dev libglx-dev
#   libglx-mesa0 libice-dev libopengl-dev libopengl0 libpthread-stubs0-dev
#   libsm-dev libunwind8 libx11-dev libxau-dev libxcb1-dev libxdmcp-dev
#   libxext-dev libxfont2 libxkbfile1 libxmuu1 libxt-dev x11-xkb-utils
#   x11proto-dev xauth xfonts-base xfonts-encodings xfonts-utils
#   xorg-sgml-doctools xserver-common xtrans-dev
# Suggested packages:
#   libice-doc libsm-doc libx11-doc libxcb-doc libxext-doc libxt-doc
# Recommended packages:
#   libgl1-amber-dri
# The following NEW packages will be installed:
#   freeglut3 freeglut3-dev libegl-dev libegl-mesa0 libegl1 libfontenc1
#   libgl-dev libgl1-mesa-dev libgles-dev libgles1 libgles2 libglu1-mesa
#   libglu1-mesa-dev libglvnd-core-dev libglvnd-dev libglx-dev libice-dev
#   libopengl-dev libopengl0 libpthread-stubs0-dev libsm-dev libunwind8
#   libx11-dev libxau-dev libxcb1-dev libxdmcp-dev libxext-dev libxfont2
#   libxkbfile1 libxmuu1 libxt-dev x11-xkb-utils x11proto-dev xauth xfonts-base
#   xfonts-encodings xfonts-utils xorg-sgml-doctools xserver-common xtrans-dev
#   xvfb
# The following packages will be upgraded:
#   libgbm1 libgl1-mesa-dri libglapi-mesa libglx-mesa0
# 4 upgraded, 41 newly installed, 0 to remove and 102 not upgraded.
# Need to get 19.3 MB of archives.
# After this operation, 28.2 MB of additional disk space will be used.
# Get:1 http://ports.ubuntu.com/ubuntu-ports jammy/main arm64 libxmuu1 arm64 2:1.1.3-3 [10.4 kB]
# Get:2 http://ports.ubuntu.com/ubuntu-ports jammy/main arm64 xauth arm64 1:1.1-1build2 [26.8 kB]
# Get:3 http://ports.ubuntu.com/ubuntu-ports jammy/universe arm64 freeglut3 arm64 2.8.1-6 [68.7 kB]
# Get:4 http://ports.ubuntu.com/ubuntu-ports jammy/main arm64 xorg-sgml-doctools all 1:1.11-1.1 [10.9 kB]
# Get:5 http://ports.ubuntu.com/ubuntu-ports jammy/main arm64 x11proto-dev all 2021.5-1 [604 kB]
# Get:6 http://ports.ubuntu.com/ubuntu-ports jammy/main arm64 libxau-dev arm64 1:1.0.9-1build5 [10.1 kB]
# Get:7 http://ports.ubuntu.com/ubuntu-ports jammy/main arm64 libxdmcp-dev arm64 1:1.1.3-0ubuntu5 [26.4 kB]
# Get:8 http://ports.ubuntu.com/ubuntu-ports jammy/main arm64 xtrans-dev all 1.4.0-1 [68.9 kB]
# Get:9 http://ports.ubuntu.com/ubuntu-ports jammy/main arm64 libpthread-stubs0-dev arm64 0.4-1build2 [5,496 B]
# Get:10 http://ports.ubuntu.com/ubuntu-ports jammy/main arm64 libxcb1-dev arm64 1.14-3ubuntu3 [90.6 kB]
# Get:11 http://ports.ubuntu.com/ubuntu-ports jammy-updates/main arm64 libx11-dev arm64 2:1.7.5-1ubuntu0.3 [746 kB]
# Get:12 http://ports.ubuntu.com/ubuntu-ports jammy/main arm64 libglx-dev arm64 1.4.0-1 [14.1 kB]
# Get:13 http://ports.ubuntu.com/ubuntu-ports jammy/main arm64 libgl-dev arm64 1.4.0-1 [102 kB]
# Get:14 http://ports.ubuntu.com/ubuntu-ports jammy/main arm64 libglvnd-core-dev arm64 1.4.0-1 [12.7 kB]
# Get:15 http://ports.ubuntu.com/ubuntu-ports jammy-updates/main arm64 libgbm1 arm64 23.2.1-1ubuntu3.1~22.04.2 [33.7 kB]
# Get:16 http://ports.ubuntu.com/ubuntu-ports jammy-updates/main arm64 libgl1-mesa-dri arm64 23.2.1-1ubuntu3.1~22.04.2 [8,093 kB]
# Get:17 http://ports.ubuntu.com/ubuntu-ports jammy-updates/main arm64 libglx-mesa0 arm64 23.2.1-1ubuntu3.1~22.04.2 [165 kB]
# Get:18 http://ports.ubuntu.com/ubuntu-ports jammy-updates/main arm64 libglapi-mesa arm64 23.2.1-1ubuntu3.1~22.04.2 [50.5 kB]
# Get:19 http://ports.ubuntu.com/ubuntu-ports jammy-updates/main arm64 libegl-mesa0 arm64 23.2.1-1ubuntu3.1~22.04.2 [117 kB]
# Get:20 http://ports.ubuntu.com/ubuntu-ports jammy/main arm64 libegl1 arm64 1.4.0-1 [28.8 kB]
# Get:21 http://ports.ubuntu.com/ubuntu-ports jammy/main arm64 libegl-dev arm64 1.4.0-1 [18.0 kB]
# Get:22 http://ports.ubuntu.com/ubuntu-ports jammy/main arm64 libgles1 arm64 1.4.0-1 [11.8 kB]
# Get:23 http://ports.ubuntu.com/ubuntu-ports jammy/main arm64 libgles2 arm64 1.4.0-1 [18.8 kB]
# Get:24 http://ports.ubuntu.com/ubuntu-ports jammy/main arm64 libgles-dev arm64 1.4.0-1 [49.4 kB]
# Get:25 http://ports.ubuntu.com/ubuntu-ports jammy/main arm64 libopengl0 arm64 1.4.0-1 [38.6 kB]
# Get:26 http://ports.ubuntu.com/ubuntu-ports jammy/main arm64 libopengl-dev arm64 1.4.0-1 [3,400 B]
# Get:27 http://ports.ubuntu.com/ubuntu-ports jammy/main arm64 libglvnd-dev arm64 1.4.0-1 [3,164 B]
# Get:28 http://ports.ubuntu.com/ubuntu-ports jammy-updates/main arm64 libgl1-mesa-dev arm64 23.2.1-1ubuntu3.1~22.04.2 [6,842 B]
# Get:29 http://ports.ubuntu.com/ubuntu-ports jammy/main arm64 libglu1-mesa arm64 9.0.2-1 [132 kB]
# Get:30 http://ports.ubuntu.com/ubuntu-ports jammy/main arm64 libglu1-mesa-dev arm64 9.0.2-1 [217 kB]
# Get:31 http://ports.ubuntu.com/ubuntu-ports jammy/main arm64 libxext-dev arm64 2:1.3.4-1build1 [85.5 kB]
# Get:32 http://ports.ubuntu.com/ubuntu-ports jammy/main arm64 libice-dev arm64 2:1.0.10-1build2 [52.1 kB]
# Get:33 http://ports.ubuntu.com/ubuntu-ports jammy/main arm64 libsm-dev arm64 2:1.2.3-1build2 [18.2 kB]
# Get:34 http://ports.ubuntu.com/ubuntu-ports jammy/main arm64 libxt-dev arm64 1:1.2.1-1 [403 kB]
# Get:35 http://ports.ubuntu.com/ubuntu-ports jammy/universe arm64 freeglut3-dev arm64 2.8.1-6 [123 kB]
# Get:36 http://ports.ubuntu.com/ubuntu-ports jammy/main arm64 libfontenc1 arm64 1:1.1.4-1build3 [14.1 kB]
# Get:37 http://ports.ubuntu.com/ubuntu-ports jammy-updates/main arm64 libunwind8 arm64 1.3.2-2build2.1 [53.4 kB]
# Get:38 http://ports.ubuntu.com/ubuntu-ports jammy/main arm64 libxfont2 arm64 1:2.0.5-1build1 [90.0 kB]
# Get:39 http://ports.ubuntu.com/ubuntu-ports jammy/main arm64 libxkbfile1 arm64 1:1.1.0-1build3 [71.2 kB]
# Get:40 http://ports.ubuntu.com/ubuntu-ports jammy/main arm64 x11-xkb-utils arm64 7.7+5build4 [168 kB]
# Get:41 http://ports.ubuntu.com/ubuntu-ports jammy/main arm64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:42 http://ports.ubuntu.com/ubuntu-ports jammy/main arm64 xfonts-utils arm64 1:7.7+6build2 [93.6 kB]
# Get:43 http://ports.ubuntu.com/ubuntu-ports jammy/main arm64 xfonts-base all 1:1.0.5 [5,896 kB]
# Get:44 http://ports.ubuntu.com/ubuntu-ports jammy-updates/main arm64 xserver-common all 2:21.1.4-2ubuntu1.7~22.04.11 [28.6 kB]
# Get:45 http://ports.ubuntu.com/ubuntu-ports jammy-updates/universe arm64 xvfb arm64 2:21.1.4-2ubuntu1.7~22.04.11 [855 kB]
# Fetched 19.3 MB in 15s (1,253 kB/s)
# debconf: delaying package configuration, since apt-utils is not installed
# Selecting previously unselected package libxmuu1:arm64.
# (Reading database ... 49687 files and directories currently installed.)
# Preparing to unpack .../00-libxmuu1_2%3a1.1.3-3_arm64.deb ...
# Unpacking libxmuu1:arm64 (2:1.1.3-3) ...
# Selecting previously unselected package xauth.
# Preparing to unpack .../01-xauth_1%3a1.1-1build2_arm64.deb ...
# Unpacking xauth (1:1.1-1build2) ...
# Selecting previously unselected package freeglut3:arm64.
# Preparing to unpack .../02-freeglut3_2.8.1-6_arm64.deb ...
# Unpacking freeglut3:arm64 (2.8.1-6) ...
# Selecting previously unselected package xorg-sgml-doctools.
# Preparing to unpack .../03-xorg-sgml-doctools_1%3a1.11-1.1_all.deb ...
# Unpacking xorg-sgml-doctools (1:1.11-1.1) ...
# Selecting previously unselected package x11proto-dev.
# Preparing to unpack .../04-x11proto-dev_2021.5-1_all.deb ...
# Unpacking x11proto-dev (2021.5-1) ...
# Selecting previously unselected package libxau-dev:arm64.
# Preparing to unpack .../05-libxau-dev_1%3a1.0.9-1build5_arm64.deb ...
# Unpacking libxau-dev:arm64 (1:1.0.9-1build5) ...
# Selecting previously unselected package libxdmcp-dev:arm64.
# Preparing to unpack .../06-libxdmcp-dev_1%3a1.1.3-0ubuntu5_arm64.deb ...
# Unpacking libxdmcp-dev:arm64 (1:1.1.3-0ubuntu5) ...
# Selecting previously unselected package xtrans-dev.
# Preparing to unpack .../07-xtrans-dev_1.4.0-1_all.deb ...
# Unpacking xtrans-dev (1.4.0-1) ...
# Selecting previously unselected package libpthread-stubs0-dev:arm64.
# Preparing to unpack .../08-libpthread-stubs0-dev_0.4-1build2_arm64.deb ...
# Unpacking libpthread-stubs0-dev:arm64 (0.4-1build2) ...
# Selecting previously unselected package libxcb1-dev:arm64.
# Preparing to unpack .../09-libxcb1-dev_1.14-3ubuntu3_arm64.deb ...
# Unpacking libxcb1-dev:arm64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libx11-dev:arm64.
# Preparing to unpack .../10-libx11-dev_2%3a1.7.5-1ubuntu0.3_arm64.deb ...
# Unpacking libx11-dev:arm64 (2:1.7.5-1ubuntu0.3) ...
# Selecting previously unselected package libglx-dev:arm64.
# Preparing to unpack .../11-libglx-dev_1.4.0-1_arm64.deb ...
# Unpacking libglx-dev:arm64 (1.4.0-1) ...
# Selecting previously unselected package libgl-dev:arm64.
# Preparing to unpack .../12-libgl-dev_1.4.0-1_arm64.deb ...
# Unpacking libgl-dev:arm64 (1.4.0-1) ...
# Selecting previously unselected package libglvnd-core-dev:arm64.
# Preparing to unpack .../13-libglvnd-core-dev_1.4.0-1_arm64.deb ...
# Unpacking libglvnd-core-dev:arm64 (1.4.0-1) ...
# Preparing to unpack .../14-libgbm1_23.2.1-1ubuntu3.1~22.04.2_arm64.deb ...
# Unpacking libgbm1:arm64 (23.2.1-1ubuntu3.1~22.04.2) over (23.0.4-0ubuntu1~22.04.1) ...
# Preparing to unpack .../15-libgl1-mesa-dri_23.2.1-1ubuntu3.1~22.04.2_arm64.deb ...
# Unpacking libgl1-mesa-dri:arm64 (23.2.1-1ubuntu3.1~22.04.2) over (23.0.4-0ubuntu1~22.04.1) ...
# Preparing to unpack .../16-libglx-mesa0_23.2.1-1ubuntu3.1~22.04.2_arm64.deb ...
# Unpacking libglx-mesa0:arm64 (23.2.1-1ubuntu3.1~22.04.2) over (23.0.4-0ubuntu1~22.04.1) ...
# Preparing to unpack .../17-libglapi-mesa_23.2.1-1ubuntu3.1~22.04.2_arm64.deb ...
# Unpacking libglapi-mesa:arm64 (23.2.1-1ubuntu3.1~22.04.2) over (23.0.4-0ubuntu1~22.04.1) ...
# Selecting previously unselected package libegl-mesa0:arm64.
# Preparing to unpack .../18-libegl-mesa0_23.2.1-1ubuntu3.1~22.04.2_arm64.deb ...
# Unpacking libegl-mesa0:arm64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Selecting previously unselected package libegl1:arm64.
# Preparing to unpack .../19-libegl1_1.4.0-1_arm64.deb ...
# Unpacking libegl1:arm64 (1.4.0-1) ...
# Selecting previously unselected package libegl-dev:arm64.
# Preparing to unpack .../20-libegl-dev_1.4.0-1_arm64.deb ...
# Unpacking libegl-dev:arm64 (1.4.0-1) ...
# Selecting previously unselected package libgles1:arm64.
# Preparing to unpack .../21-libgles1_1.4.0-1_arm64.deb ...
# Unpacking libgles1:arm64 (1.4.0-1) ...
# Selecting previously unselected package libgles2:arm64.
# Preparing to unpack .../22-libgles2_1.4.0-1_arm64.deb ...
# Unpacking libgles2:arm64 (1.4.0-1) ...
# Selecting previously unselected package libgles-dev:arm64.
# Preparing to unpack .../23-libgles-dev_1.4.0-1_arm64.deb ...
# Unpacking libgles-dev:arm64 (1.4.0-1) ...
# Selecting previously unselected package libopengl0:arm64.
# Preparing to unpack .../24-libopengl0_1.4.0-1_arm64.deb ...
# Unpacking libopengl0:arm64 (1.4.0-1) ...
# Selecting previously unselected package libopengl-dev:arm64.
# Preparing to unpack .../25-libopengl-dev_1.4.0-1_arm64.deb ...
# Unpacking libopengl-dev:arm64 (1.4.0-1) ...
# Selecting previously unselected package libglvnd-dev:arm64.
# Preparing to unpack .../26-libglvnd-dev_1.4.0-1_arm64.deb ...
# Unpacking libglvnd-dev:arm64 (1.4.0-1) ...
# Selecting previously unselected package libgl1-mesa-dev:arm64.
# Preparing to unpack .../27-libgl1-mesa-dev_23.2.1-1ubuntu3.1~22.04.2_arm64.deb ...
# Unpacking libgl1-mesa-dev:arm64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Selecting previously unselected package libglu1-mesa:arm64.
# Preparing to unpack .../28-libglu1-mesa_9.0.2-1_arm64.deb ...
# Unpacking libglu1-mesa:arm64 (9.0.2-1) ...
# Selecting previously unselected package libglu1-mesa-dev:arm64.
# Preparing to unpack .../29-libglu1-mesa-dev_9.0.2-1_arm64.deb ...
# Unpacking libglu1-mesa-dev:arm64 (9.0.2-1) ...
# Selecting previously unselected package libxext-dev:arm64.
# Preparing to unpack .../30-libxext-dev_2%3a1.3.4-1build1_arm64.deb ...
# Unpacking libxext-dev:arm64 (2:1.3.4-1build1) ...
# Selecting previously unselected package libice-dev:arm64.
# Preparing to unpack .../31-libice-dev_2%3a1.0.10-1build2_arm64.deb ...
# Unpacking libice-dev:arm64 (2:1.0.10-1build2) ...
# Selecting previously unselected package libsm-dev:arm64.
# Preparing to unpack .../32-libsm-dev_2%3a1.2.3-1build2_arm64.deb ...
# Unpacking libsm-dev:arm64 (2:1.2.3-1build2) ...
# Selecting previously unselected package libxt-dev:arm64.
# Preparing to unpack .../33-libxt-dev_1%3a1.2.1-1_arm64.deb ...
# Unpacking libxt-dev:arm64 (1:1.2.1-1) ...
# Selecting previously unselected package freeglut3-dev:arm64.
# Preparing to unpack .../34-freeglut3-dev_2.8.1-6_arm64.deb ...
# Unpacking freeglut3-dev:arm64 (2.8.1-6) ...
# Selecting previously unselected package libfontenc1:arm64.
# Preparing to unpack .../35-libfontenc1_1%3a1.1.4-1build3_arm64.deb ...
# Unpacking libfontenc1:arm64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libunwind8:arm64.
# Preparing to unpack .../36-libunwind8_1.3.2-2build2.1_arm64.deb ...
# Unpacking libunwind8:arm64 (1.3.2-2build2.1) ...
# Selecting previously unselected package libxfont2:arm64.
# Preparing to unpack .../37-libxfont2_1%3a2.0.5-1build1_arm64.deb ...
# Unpacking libxfont2:arm64 (1:2.0.5-1build1) ...
# Selecting previously unselected package libxkbfile1:arm64.
# Preparing to unpack .../38-libxkbfile1_1%3a1.1.0-1build3_arm64.deb ...
# Unpacking libxkbfile1:arm64 (1:1.1.0-1build3) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../39-x11-xkb-utils_7.7+5build4_arm64.deb ...
# Unpacking x11-xkb-utils (7.7+5build4) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../40-xfonts-encodings_1%3a1.0.5-0ubuntu2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../41-xfonts-utils_1%3a7.7+6build2_arm64.deb ...
# Unpacking xfonts-utils (1:7.7+6build2) ...
# Selecting previously unselected package xfonts-base.
# Preparing to unpack .../42-xfonts-base_1%3a1.0.5_all.deb ...
# Unpacking xfonts-base (1:1.0.5) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../43-xserver-common_2%3a21.1.4-2ubuntu1.7~22.04.11_all.deb ...
# Unpacking xserver-common (2:21.1.4-2ubuntu1.7~22.04.11) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../44-xvfb_2%3a21.1.4-2ubuntu1.7~22.04.11_arm64.deb ...
# Unpacking xvfb (2:21.1.4-2ubuntu1.7~22.04.11) ...
# Setting up freeglut3:arm64 (2.8.1-6) ...
# Setting up libglvnd-core-dev:arm64 (1.4.0-1) ...
# Setting up libgbm1:arm64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Setting up libunwind8:arm64 (1.3.2-2build2.1) ...
# Setting up libpthread-stubs0-dev:arm64 (0.4-1build2) ...
# Setting up libopengl0:arm64 (1.4.0-1) ...
# Setting up xtrans-dev (1.4.0-1) ...
# Setting up libfontenc1:arm64 (1:1.1.4-1build3) ...
# Setting up libgles2:arm64 (1.4.0-1) ...
# Setting up libgles1:arm64 (1.4.0-1) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Setting up libglapi-mesa:arm64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Setting up xorg-sgml-doctools (1:1.11-1.1) ...
# Setting up libglu1-mesa:arm64 (9.0.2-1) ...
# Setting up libxkbfile1:arm64 (1:1.1.0-1build3) ...
# Setting up libopengl-dev:arm64 (1.4.0-1) ...
# Setting up libxfont2:arm64 (1:2.0.5-1build1) ...
# Setting up libxmuu1:arm64 (2:1.1.3-3) ...
# Setting up x11proto-dev (2021.5-1) ...
# Setting up libxau-dev:arm64 (1:1.0.9-1build5) ...
# Setting up libice-dev:arm64 (2:1.0.10-1build2) ...
# Setting up libsm-dev:arm64 (2:1.2.3-1build2) ...
# Setting up x11-xkb-utils (7.7+5build4) ...
# Setting up libgl1-mesa-dri:arm64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Setting up xfonts-utils (1:7.7+6build2) ...
# Setting up libxdmcp-dev:arm64 (1:1.1.3-0ubuntu5) ...
# Setting up xfonts-base (1:1.0.5) ...
# Setting up libegl-mesa0:arm64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Setting up xauth (1:1.1-1build2) ...
# Setting up libegl1:arm64 (1.4.0-1) ...
# Setting up xserver-common (2:21.1.4-2ubuntu1.7~22.04.11) ...
# Setting up libglx-mesa0:arm64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Setting up libxcb1-dev:arm64 (1.14-3ubuntu3) ...
# Setting up xvfb (2:21.1.4-2ubuntu1.7~22.04.11) ...
# Setting up libx11-dev:arm64 (2:1.7.5-1ubuntu0.3) ...
# Setting up libxt-dev:arm64 (1:1.2.1-1) ...
# Setting up libxext-dev:arm64 (2:1.3.4-1build1) ...
# Setting up libglx-dev:arm64 (1.4.0-1) ...
# Setting up libgl-dev:arm64 (1.4.0-1) ...
# Setting up libegl-dev:arm64 (1.4.0-1) ...
# Setting up libglu1-mesa-dev:arm64 (9.0.2-1) ...
# Setting up libgles-dev:arm64 (1.4.0-1) ...
# Setting up libglvnd-dev:arm64 (1.4.0-1) ...
# Setting up libgl1-mesa-dev:arm64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Setting up freeglut3-dev:arm64 (2.8.1-6) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Requirement already satisfied: tensorflow in /opt/conda/lib/python3.11/site-packages (2.14.0)
# Collecting tensorflow
#   Downloading tensorflow-2.17.0-cp311-cp311-manylinux_2_17_aarch64.manylinux2014_aarch64.whl.metadata (4.1 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (16.0.6)
# Collecting ml-dtypes<0.5.0,>=0.3.1 (from tensorflow)
#   Downloading ml_dtypes-0.4.0-cp311-cp311-manylinux_2_17_aarch64.manylinux2014_aarch64.whl.metadata (20 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (4.24.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (4.8.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.59.0)
# Collecting tensorboard<2.18,>=2.17 (from tensorflow)
#   Downloading tensorboard-2.17.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting keras>=3.2.0 (from tensorflow)
#   Downloading keras-3.5.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.24.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.41.2)
# Collecting rich (from keras>=3.2.0->tensorflow)
#   Downloading rich-13.8.1-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.2.0->tensorflow)
#   Downloading namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# Collecting optree (from keras>=3.2.0->tensorflow)
#   Downloading optree-0.12.1-cp311-cp311-manylinux_2_17_aarch64.manylinux2014_aarch64.whl.metadata (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.8/47.8 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2023.7.22)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.5)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.3)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.2.0->tensorflow)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.11/site-packages (from rich->keras>=3.2.0->tensorflow) (2.16.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading tensorflow-2.17.0-cp311-cp311-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (223.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.9/223.9 MB 3.1 MB/s eta 0:00:0000:0100:02
# Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Downloading keras-3.5.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 5.7 MB/s eta 0:00:00a 0:00:01
# Downloading ml_dtypes-0.4.0-cp311-cp311-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 7.4 MB/s eta 0:00:0000:0100:01
# Downloading tensorboard-2.17.1-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 5.9 MB/s eta 0:00:00a 0:00:01
# Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Downloading optree-0.12.1-cp311-cp311-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.4/319.4 kB 7.4 MB/s eta 0:00:00a 0:00:01
# Downloading rich-13.8.1-py3-none-any.whl (241 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.6/241.6 kB 7.0 MB/s eta 0:00:00
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 6.2 MB/s eta 0:00:00
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, flatbuffers, optree, ml-dtypes, mdurl, tensorboard, markdown-it-py, rich, keras, tensorflow
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 23.5.26
#     Uninstalling flatbuffers-23.5.26:
#       Successfully uninstalled flatbuffers-23.5.26
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.2.0
#     Uninstalling ml-dtypes-0.2.0:
#       Successfully uninstalled ml-dtypes-0.2.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.14.1
#     Uninstalling tensorboard-2.14.1:
#       Successfully uninstalled tensorboard-2.14.1
#   Attempting uninstall: keras
#     Found existing installation: keras 2.14.0
#     Uninstalling keras-2.14.0:
#       Successfully uninstalled keras-2.14.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.14.0
#     Uninstalling tensorflow-2.14.0:
#       Successfully uninstalled tensorflow-2.14.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-cpu-aws 2.14.0 requires keras<2.15,>=2.14.0, but you have keras 3.5.0 which is incompatible.
# tensorflow-cpu-aws 2.14.0 requires ml-dtypes==0.2.0, but you have ml-dtypes 0.4.0 which is incompatible.
# tensorflow-cpu-aws 2.14.0 requires tensorboard<2.15,>=2.14, but you have tensorboard 2.17.1 which is incompatible.
# Successfully installed flatbuffers-24.3.25 keras-3.5.0 markdown-it-py-3.0.0 mdurl-0.1.2 ml-dtypes-0.4.0 namex-0.0.8 optree-0.12.1 rich-13.8.1 tensorboard-2.17.1 tensorflow-2.17.0
# Requirement already satisfied: scikit-image in /opt/conda/lib/python3.11/site-packages (0.22.0)
# Collecting scikit-image
#   Downloading scikit_image-0.24.0-cp311-cp311-manylinux_2_17_aarch64.manylinux2014_aarch64.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.23 in /opt/conda/lib/python3.11/site-packages (from scikit-image) (1.24.4)
# Requirement already satisfied: scipy>=1.9 in /opt/conda/lib/python3.11/site-packages (from scikit-image) (1.11.3)
# Requirement already satisfied: networkx>=2.8 in /opt/conda/lib/python3.11/site-packages (from scikit-image) (3.2)
# Requirement already satisfied: pillow>=9.1 in /opt/conda/lib/python3.11/site-packages (from scikit-image) (10.1.0)
# Collecting imageio>=2.33 (from scikit-image)
#   Downloading imageio-2.35.1-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/conda/lib/python3.11/site-packages (from scikit-image) (2023.9.26)
# Requirement already satisfied: packaging>=21 in /opt/conda/lib/python3.11/site-packages (from scikit-image) (23.2)
# Collecting lazy-loader>=0.4 (from scikit-image)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Downloading scikit_image-0.24.0-cp311-cp311-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (14.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.2/14.2 MB 2.1 MB/s eta 0:00:0000:0100:01
# Downloading imageio-2.35.1-py3-none-any.whl (315 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.4/315.4 kB 6.4 MB/s eta 0:00:00a 0:00:01
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Installing collected packages: lazy-loader, imageio, scikit-image
#   Attempting uninstall: lazy-loader
#     Found existing installation: lazy_loader 0.3
#     Uninstalling lazy_loader-0.3:
#       Successfully uninstalled lazy_loader-0.3
#   Attempting uninstall: imageio
#     Found existing installation: imageio 2.31.5
#     Uninstalling imageio-2.31.5:
#       Successfully uninstalled imageio-2.31.5
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.22.0
#     Uninstalling scikit-image-0.22.0:
#       Successfully uninstalled scikit-image-0.22.0
# Successfully installed imageio-2.35.1 lazy-loader-0.4 scikit-image-0.24.0
# Collecting tf-agents
#   Downloading tf_agents-0.19.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: absl-py>=0.6.1 in /opt/conda/lib/python3.11/site-packages (from tf-agents) (2.0.0)
# Requirement already satisfied: cloudpickle>=1.3 in /opt/conda/lib/python3.11/site-packages (from tf-agents) (3.0.0)
# Collecting gin-config>=0.4.0 (from tf-agents)
#   Downloading gin_config-0.5.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting gym<=0.23.0,>=0.17.0 (from tf-agents)
#   Downloading gym-0.23.0.tar.gz (624 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 624.4/624.4 kB 4.2 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.19.0 in /opt/conda/lib/python3.11/site-packages (from tf-agents) (1.24.4)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.11/site-packages (from tf-agents) (10.1.0)
# Requirement already satisfied: six>=1.10.0 in /opt/conda/lib/python3.11/site-packages (from tf-agents) (1.16.0)
# Requirement already satisfied: protobuf>=3.11.3 in /opt/conda/lib/python3.11/site-packages (from tf-agents) (4.24.3)
# Requirement already satisfied: wrapt>=1.11.1 in /opt/conda/lib/python3.11/site-packages (from tf-agents) (1.14.1)
# Collecting typing-extensions==4.5.0 (from tf-agents)
#   Downloading typing_extensions-4.5.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting pygame==2.1.3 (from tf-agents)
#   Downloading pygame-2.1.3-cp311-cp311-manylinux_2_17_aarch64.manylinux2014_aarch64.whl.metadata (9.3 kB)
# Collecting tensorflow-probability~=0.23.0 (from tf-agents)
#   Downloading tensorflow_probability-0.23.0-py2.py3-none-any.whl.metadata (13 kB)
# Collecting gym-notices>=0.0.4 (from gym<=0.23.0,>=0.17.0->tf-agents)
#   Downloading gym_notices-0.0.8-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.11/site-packages (from tensorflow-probability~=0.23.0->tf-agents) (5.1.1)
# Requirement already satisfied: gast>=0.3.2 in /opt/conda/lib/python3.11/site-packages (from tensorflow-probability~=0.23.0->tf-agents) (0.5.4)
# Collecting dm-tree (from tensorflow-probability~=0.23.0->tf-agents)
#   Downloading dm_tree-0.1.8-cp311-cp311-manylinux_2_17_aarch64.manylinux2014_aarch64.whl.metadata (1.9 kB)
# Downloading tf_agents-0.19.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 3.8 MB/s eta 0:00:0000:0100:01
# Downloading pygame-2.1.3-cp311-cp311-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 4.2 MB/s eta 0:00:0000:0100:01
# Downloading typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Downloading gin_config-0.5.0-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 8.0 MB/s eta 0:00:00
# Downloading tensorflow_probability-0.23.0-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 3.8 MB/s eta 0:00:0000:0100:01
# Downloading gym_notices-0.0.8-py3-none-any.whl (3.0 kB)
# Downloading dm_tree-0.1.8-cp311-cp311-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (146 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.7/146.7 kB 8.8 MB/s eta 0:00:00
# Building wheels for collected packages: gym
#   Building wheel for gym (pyproject.toml) ... done
#   Created wheel for gym: filename=gym-0.23.0-py3-none-any.whl size=697629 sha256=a777553630bc2d4cf9de68a4846467ae6132f3dd43b8f5bbbc119fddc7a1ba1c
#   Stored in directory: /home/jovyan/.cache/pip/wheels/bf/19/ce/d2b762b6d61115bf0b4260ca59650ba2d55d49f34f61e095f6
# Successfully built gym
# Installing collected packages: gym-notices, gin-config, dm-tree, typing-extensions, tensorflow-probability, pygame, gym, tf-agents
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.8.0
#     Uninstalling typing_extensions-4.8.0:
#       Successfully uninstalled typing_extensions-4.8.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-cpu-aws 2.14.0 requires keras<2.15,>=2.14.0, but you have keras 3.5.0 which is incompatible.
# tensorflow-cpu-aws 2.14.0 requires ml-dtypes==0.2.0, but you have ml-dtypes 0.4.0 which is incompatible.
# tensorflow-cpu-aws 2.14.0 requires tensorboard<2.15,>=2.14, but you have tensorboard 2.17.1 which is incompatible.
# Successfully installed dm-tree-0.1.8 gin-config-0.5.0 gym-0.23.0 gym-notices-0.0.8 pygame-2.1.3 tensorflow-probability-0.23.0 tf-agents-0.19.0 typing-extensions-4.5.0
# Collecting pyglet
#   Downloading pyglet-2.0.17-py3-none-any.whl.metadata (7.9 kB)
# Collecting xvfbwrapper
#   Downloading xvfbwrapper-0.2.9.tar.gz (5.6 kB)
#   Preparing metadata (setup.py) ... done
# Downloading pyglet-2.0.17-py3-none-any.whl (936 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 936.6/936.6 kB 2.7 MB/s eta 0:00:0000:0100:01
# Building wheels for collected packages: xvfbwrapper
#   Building wheel for xvfbwrapper (setup.py) ... done
#   Created wheel for xvfbwrapper: filename=xvfbwrapper-0.2.9-py3-none-any.whl size=5009 sha256=6ef916e9404cc710c34e7171fa799a6fde5e1678b84b7e5e1912f9057c0ad33a
#   Stored in directory: /home/jovyan/.cache/pip/wheels/ba/5c/40/945b2f824d1770d8b13123f3f598562449be8fc8aa51acfff2
# Successfully built xvfbwrapper
# Installing collected packages: xvfbwrapper, pyglet
# Successfully installed pyglet-2.0.17 xvfbwrapper-0.2.9
# Collecting tf-keras
#   Downloading tf_keras-2.17.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: tensorflow<2.18,>=2.17 in /opt/conda/lib/python3.11/site-packages (from tf-keras) (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /opt/conda/lib/python3.11/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (16.0.6)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.11/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (3.3.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/conda/lib/python3.11/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (4.24.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (2.31.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.11/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.11/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (1.59.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /opt/conda/lib/python3.11/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (0.34.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /opt/conda/lib/python3.11/site-packages (from tensorflow<2.18,>=2.17->tf-keras) (1.24.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow<2.18,>=2.17->tf-keras) (0.41.2)
# Requirement already satisfied: rich in /opt/conda/lib/python3.11/site-packages (from keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (13.8.1)
# Requirement already satisfied: namex in /opt/conda/lib/python3.11/site-packages (from keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (0.0.8)
# Requirement already satisfied: optree in /opt/conda/lib/python3.11/site-packages (from keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.18,>=2.17->tf-keras) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.18,>=2.17->tf-keras) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.18,>=2.17->tf-keras) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.18,>=2.17->tf-keras) (2023.7.22)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow<2.18,>=2.17->tf-keras) (3.5)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow<2.18,>=2.17->tf-keras) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow<2.18,>=2.17->tf-keras) (3.0.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow<2.18,>=2.17->tf-keras) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.11/site-packages (from rich->keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.11/site-packages (from rich->keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (0.1.2)
# Downloading tf_keras-2.17.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 2.0 MB/s eta 0:00:0000:0100:01
# Installing collected packages: tf-keras
# Successfully installed tf-keras-2.17.0
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.7-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: keras in /opt/conda/lib/python3.11/site-packages (from keras-tuner) (3.5.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from keras-tuner) (23.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from keras-tuner) (2.31.0)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Requirement already satisfied: absl-py in /opt/conda/lib/python3.11/site-packages (from keras->keras-tuner) (2.0.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from keras->keras-tuner) (1.24.4)
# Requirement already satisfied: rich in /opt/conda/lib/python3.11/site-packages (from keras->keras-tuner) (13.8.1)
# Requirement already satisfied: namex in /opt/conda/lib/python3.11/site-packages (from keras->keras-tuner) (0.0.8)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.11/site-packages (from keras->keras-tuner) (3.10.0)
# Requirement already satisfied: optree in /opt/conda/lib/python3.11/site-packages (from keras->keras-tuner) (0.12.1)
# Requirement already satisfied: ml-dtypes in /opt/conda/lib/python3.11/site-packages (from keras->keras-tuner) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->keras-tuner) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->keras-tuner) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->keras-tuner) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->keras-tuner) (2023.7.22)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/conda/lib/python3.11/site-packages (from optree->keras->keras-tuner) (4.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.11/site-packages (from rich->keras->keras-tuner) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.11/site-packages (from rich->keras->keras-tuner) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner) (0.1.2)
# Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 3.9 MB/s eta 0:00:00
# Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.7 kt-legacy-1.0.5
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (2.1.1)
# Collecting pandas-ta
#   Downloading pandas_ta-0.3.14b.tar.gz (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.1/115.1 kB 3.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (1.24.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Building wheels for collected packages: pandas-ta
#   Building wheel for pandas-ta (setup.py) ... done
#   Created wheel for pandas-ta: filename=pandas_ta-0.3.14b0-py3-none-any.whl size=218908 sha256=6ae8cb58e25d3f28f246958eca68efb40d573d8343bae3477317df251d2d70df
#   Stored in directory: /home/jovyan/.cache/pip/wheels/7f/33/8b/50b245c5c65433cd8f5cb24ac15d97e5a3db2d41a8b6ae957d
# Successfully built pandas-ta
# Installing collected packages: pandas-ta
# Successfully installed pandas-ta-0.3.14b0

# %%
import os
# Keep using keras-2 (tf-keras) rather than keras-3 (keras).
os.environ['TF_USE_LEGACY_KERAS'] = '1'

# %%
# Load the TensorBoard notebook extension.
#%load_ext tensorboard

# %%
from __future__ import absolute_import, division, print_function

import base64
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

import tensorflow as tf

from tf_agents.drivers import dynamic_step_driver
from tf_agents.environments import suite_gym
from tf_agents.environments import tf_py_environment
from tf_agents.eval import metric_utils
from tf_agents.metrics import tf_metrics
from tf_agents.policies import random_tf_policy, policy_saver
from tf_agents.replay_buffers import tf_uniform_replay_buffer
from tf_agents.trajectories import trajectory
from tf_agents.utils import common

from envs.macd_env import MacdEnv
from envs.adx_env import AdxEnv
from envs.rsi_env import RsiEnv
from envs.moving_average_env import MovingAverageEnv
from envs.combined_env import CombinedEnv

from utils import load_dataset

import sys
from datetime import datetime

# %%
## Helper functions

def create_env(env_type: str, df, window_size, frame_bound):
    if env_type == 'macd':
        return MacdEnv(df=df, window_size=window_size, frame_bound=frame_bound)

    if env_type == 'rsi':
        return RsiEnv(df=df, window_size=window_size, frame_bound=frame_bound)

    if env_type == 'adx':
        return AdxEnv(df=df, window_size=window_size, frame_bound=frame_bound)

    if env_type == 'mas':
        return MovingAverageEnv(df=df, window_size=window_size, frame_bound=frame_bound)

    if env_type == 'com':
        return CombinedEnv(df=df, window_size=window_size, frame_bound=frame_bound)

    raise NotImplementedError('unknown type')


def create_training_envs(env_type: str):
    ko_df = load_dataset('./resources/KO.csv')
    amzn_df = load_dataset('./resources/AMZN.csv')
    amd_df = load_dataset('./resources/AMD.csv')
    pypl_df = load_dataset('./resources/PYPL.csv')
    nflx_df = load_dataset('./resources/NFLX.csv')
    window_size = 10

    return [
        # KO training envs
        create_env(env_type, ko_df, window_size, (10, 120)),
        create_env(env_type, ko_df, window_size, (120, 230)),
        create_env(env_type, ko_df, window_size, (350, 470)),
        create_env(env_type, ko_df, window_size, (1000, 1120)),
        create_env(env_type, ko_df, window_size, (1700, 1820)),

        # AMZN training envs
        create_env(env_type, amzn_df, window_size, (10, 120)),
        create_env(env_type, amzn_df, window_size, (120, 230)),
        create_env(env_type, amzn_df, window_size, (350, 470)),
        create_env(env_type, amzn_df, window_size, (1000, 1120)),
        create_env(env_type, amzn_df, window_size, (1700, 1820)),

        # AMD training envs
        create_env(env_type, amd_df, window_size, (10, 120)),
        create_env(env_type, amd_df, window_size, (120, 230)),
        create_env(env_type, amd_df, window_size, (350, 470)),
        create_env(env_type, amd_df, window_size, (1000, 1120)),
        create_env(env_type, amd_df, window_size, (1700, 1820)),

        # PYPL training envs
        create_env(env_type, pypl_df, window_size, (10, 120)),
        create_env(env_type, pypl_df, window_size, (120, 230)),
        create_env(env_type, pypl_df, window_size, (350, 470)),
        create_env(env_type, pypl_df, window_size, (1000, 1120)),
        create_env(env_type, pypl_df, window_size, (1700, 1820)),

        # NFLX training envs
        create_env(env_type, nflx_df, window_size, (10, 120)),
        create_env(env_type, nflx_df, window_size, (120, 230)),
        create_env(env_type, nflx_df, window_size, (350, 470)),
        create_env(env_type, nflx_df, window_size, (1000, 1120)),
        create_env(env_type, nflx_df, window_size, (1700, 1820)),
    ]


def create_testing_env(env_type: str):
    ko_df = load_dataset('./resources/KO.csv')
    window_size = 10
    return create_env(env_type, ko_df, window_size, (2000, 2300))

# %%
from packaging import version

print("TensorFlow version: ", tf.__version__)
assert version.parse(tf.__version__).release[0] >= 2, \
    "This notebook requires TensorFlow 2.0 or above."
# Out:
# TensorFlow version:  2.17.0

# %%
PARAM_ENV_TYPE='com'


# ====================================== Create environments ======================================

train_py_envs = create_training_envs(PARAM_ENV_TYPE)
train_env_sample = tf_py_environment.TFPyEnvironment(train_py_envs[0])

eval_py_env = create_testing_env(PARAM_ENV_TYPE)
eval_env = tf_py_environment.TFPyEnvironment(eval_py_env)

# %%
import keras_tuner as kt
from tf_agents.agents.categorical_dqn import categorical_dqn_agent
from tf_agents.networks import categorical_q_network

PARAM_NUM_ATOMS = 51
PARAM_MIN_Q_VALUE = -1000
PARAM_MAX_Q_VALUE = 1000

PARAM_REPLAY_BUFFER_CAPACITY = 100000
PARAM_INITIAL_COLLECT_STEPS = 1000
PARAM_BATCH_SIZE = 64
PARAM_N_STEP_UPDATE = 1

PARAM_NUM_ITERATIONS = 200
PARAM_COLLECT_STEPS_PER_ITERATION = 500

PARAM_LOG_INTERVAL = 10
PARAM_EVAL_EPISODES = 2
PARAM_EVAL_INTERVAL = 25

EXECUTION_ID = datetime.now().strftime('%Y-%m-%d_%H%M%S')

# ====================================== Helper for Avg Return ======================================
def compute_avg_return(environment, policy, num_episodes=2):
    total_return = 0.0
    for _ in range(num_episodes):
        time_step = environment.reset()
        episode_return = 0.0

        while not time_step.is_last():
            action_step = policy.action(time_step)
            time_step = environment.step(action_step.action)
            episode_return += time_step.reward
        total_return += episode_return

    avg_return = total_return / num_episodes
    return avg_return.numpy()[0]

# Random policy
random_policy = random_tf_policy.RandomTFPolicy(train_env_sample.time_step_spec(), train_env_sample.action_spec())


class Airtos2HyperModel(kt.HyperModel):
    
    def build(self, hp):
        # Compute the number of layers for the DQN agent
        layers_list = []
        num_layers = hp.Int("n_layers", min_value=3, max_value=12)
        for i in range(num_layers):
            layers_list.append(hp.Int(f'units_{i}', min_value=32, max_value=512, step=32))
        AGENT_LAYERS = tuple(layers_list)
        
        categorical_q_net = categorical_q_network.CategoricalQNetwork(
            train_env_sample.observation_spec(),
            train_env_sample.action_spec(),
            num_atoms=PARAM_NUM_ATOMS,
            fc_layer_params=AGENT_LAYERS)
    
        optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate=hp.Choice('learning_rate', [5e-7, 5e-6, 5e-5, 5e-4, 5e-3]))
        
        train_step_counter = tf.Variable(initial_value=0, dtype='int64')
        
        agent = categorical_dqn_agent.CategoricalDqnAgent(
            train_env_sample.time_step_spec(),
            train_env_sample.action_spec(),
            categorical_q_network=categorical_q_net,
            optimizer=optimizer,
            min_q_value=PARAM_MIN_Q_VALUE,
            max_q_value=PARAM_MAX_Q_VALUE,
            n_step_update=PARAM_N_STEP_UPDATE,
            #td_errors_loss_fn=common.element_wise_squared_loss,
            gamma=0,
            train_step_counter=train_step_counter)
        agent.initialize()
        
        return agent

    
    def run(self, hp, model, trial, *args, **kwargs):
        agent = model
        # ====================================== Collect Initial Data ======================================
        replay_buffer = tf_uniform_replay_buffer.TFUniformReplayBuffer(
            data_spec=agent.collect_data_spec,
            batch_size=train_env_sample.batch_size,
            max_length=PARAM_REPLAY_BUFFER_CAPACITY)
        
        def collect_step(environment, policy):
            time_step = environment.current_time_step()
            action_step = policy.action(time_step)
            next_time_step = environment.step(action_step.action)
            traj = trajectory.from_transition(time_step, action_step, next_time_step)
            # Add trajectory to the replay buffer
            replay_buffer.add_batch(traj)
        
        # Collect initial data, using random policy
        for _ in range(PARAM_INITIAL_COLLECT_STEPS):
            collect_step(train_env_sample, random_policy)
        
        # Dataset generates trajectories with shape [BxTx...] where
        dataset = replay_buffer.as_dataset(
            num_parallel_calls=3,
            sample_batch_size=PARAM_BATCH_SIZE,
            num_steps=PARAM_N_STEP_UPDATE + 1).prefetch(3)
        
        iterator = iter(dataset)

        # ====================================== Training Loop ======================================
    
        # (Optional) Optimize by wrapping some of the code in a graph using TF function.
        agent.train = common.function(agent.train)
        
        # Reset the train step.
        agent.train_step_counter.assign(0)
        
        # Evaluate the agent's policy once before training.
        avg_return = compute_avg_return(eval_env, agent.policy, PARAM_EVAL_EPISODES)
        
        def get_random_train_env():
            idx = np.random.randint(len(train_py_envs))
            return tf_py_environment.TFPyEnvironment(train_py_envs[idx])
        
        
        train_env = get_random_train_env()
        iterations_per_env = 10

        # Create logging utilities
        LOG_DIR = f"tuner/{EXECUTION_ID}/trial_" + trial.trial_id

        file_writer = tf.summary.create_file_writer(LOG_DIR + "/metrics")
        file_writer.set_as_default()
        
        for _ in range(PARAM_NUM_ITERATIONS):
            # Collect a few steps using collect_policy and save to the replay buffer.
            for _ in range(PARAM_COLLECT_STEPS_PER_ITERATION):
                collect_step(train_env, agent.collect_policy)
        
            # Sample a batch of data from the buffer and update the agent's network.
            experience, unused_info = next(iterator)
            train_loss = agent.train(experience)
        
            step = agent.train_step_counter.numpy()
        
            # Log information
            if step % PARAM_LOG_INTERVAL == 0:
                print('step = {0}: loss = {1}'.format(step, train_loss.loss))
                #tf.summary.scalar('loss2', data=train_loss.loss, step=int64(step))
        
        
            # Evaluate agent
            if step % PARAM_EVAL_INTERVAL == 0:
                avg_return = compute_avg_return(
                    eval_env, agent.policy, PARAM_EVAL_EPISODES)
                print('step = {0}: Average Return = {1:.2f}'.format(
                    step, avg_return))
                tf.summary.scalar('average return', data=avg_return, step=step)
        
        
            # Change training env
            if step % iterations_per_env == 0:
                train_env = get_random_train_env()
    
        print("Finished execution!")
        
        avg_return = compute_avg_return(eval_env, agent.policy, PARAM_EVAL_EPISODES)

        return {
            'avg_return': avg_return
        }

# %%
class Airtos2Tunner(kt.RandomSearch):

    def run_trial(self, trial, *args, **kwargs):
        hp = trial.hyperparameters
        model = self.hypermodel.build(hp)
        return self.hypermodel.run(hp, model, trial=trial, *args, **kwargs)

# %%
tuner = Airtos2Tunner(
    hypermodel=Airtos2HyperModel(name='airtos2'),
    objective=kt.Objective(name='avg_return', direction='max'),
    max_trials=3,
    max_retries_per_trial=0,
    max_consecutive_failed_trials=3,
    directory='keras_tuner',
    project_name=f'airtos2_{EXECUTION_ID}',
    tuner_id='airtos2_tuner1',
    overwrite=False,
    executions_per_trial=1
)

tuner.search_space_summary(extended=True)

tuner.search()

best_hp = tuner.get_best_hyperparameters()[0]
print(best_hp)
# Out:
# Trial 3 Complete [00h 10m 26s]
# avg_return: 587.439697265625
#
# Best avg_return So Far: 587.439697265625
# Total elapsed time: 00h 34m 21s
# <keras_tuner.src.engine.hyperparameters.hyperparameters.HyperParameters object at 0xffffa6184ed0>

# %%
'''
# ====================================== Execution params definition ======================================
PARAM_NUM_ITERATIONS = 800
PARAM_ENV_TYPE = 'mas'
PARAM_RUN_ID = 'test_' + str(datetime.now().timestamp())

PARAM_INITIAL_COLLECT_STEPS = 10000
PARAM_COLLECT_STEPS_PER_ITERATION = 500
PARAM_REPLAY_BUFFER_CAPACITY = 100000
PARAM_BATCH_SIZE = 64

PARAM_GAMMA = 0.00 #0.99

PARAM_NUM_ATOMS = 51
PARAM_MIN_Q_VALUE = -1000
PARAM_MAX_Q_VALUE = 1000
#PARAM_N_STEP_UPDATE = 1

PARAM_LOG_INTERVAL = 10
PARAM_EVAL_EPISODES = 10
PARAM_EVAL_INTERVAL = 50
PARAM_LOG_LEARNING_RATE = 50
PARAM_CHANGE_LEARNING_RATE = 50
'''
# Out:
# "\n# ====================================== Execution params definition ======================================\nPARAM_NUM_ITERATIONS = 800\nPARAM_ENV_TYPE = 'mas'\nPARAM_RUN_ID = 'test_' + str(datetime.now().timestamp())\n\nPARAM_INITIAL_COLLECT_STEPS = 10000\nPARAM_COLLECT_STEPS_PER_ITERATION = 500\nPARAM_REPLAY_BUFFER_CAPACITY = 100000\nPARAM_BATCH_SIZE = 64\n\nPARAM_GAMMA = 0.00 #0.99\n\nPARAM_NUM_ATOMS = 51\nPARAM_MIN_Q_VALUE = -1000\nPARAM_MAX_Q_VALUE = 1000\n#PARAM_N_STEP_UPDATE = 1\n\nPARAM_LOG_INTERVAL = 10\nPARAM_EVAL_EPISODES = 10\nPARAM_EVAL_INTERVAL = 50\nPARAM_LOG_LEARNING_RATE = 50\nPARAM_CHANGE_LEARNING_RATE = 50\n"

# %%
'''
# ====================================== Create environments ======================================

train_py_envs = create_training_envs(PARAM_ENV_TYPE)
train_env_sample = tf_py_environment.TFPyEnvironment(train_py_envs[0])

eval_py_env = create_testing_env(PARAM_ENV_TYPE)
eval_env = tf_py_environment.TFPyEnvironment(eval_py_env)'''
# Out:
# '\n# ====================================== Create environments ======================================\n\ntrain_py_envs = create_training_envs(PARAM_ENV_TYPE)\ntrain_env_sample = tf_py_environment.TFPyEnvironment(train_py_envs[0])\n\neval_py_env = create_testing_env(PARAM_ENV_TYPE)\neval_env = tf_py_environment.TFPyEnvironment(eval_py_env)'

# %%
'''for VARIATION in VARIATIONS:

    PARAM_SET, PARAM_AGENT_LAYERS, PARAM_LEARNING_RATE, PARAM_N_STEP_UPDATE = VARIATION
    
    # Create logging utilities
    LOG_DIR = "logs/scalars/" + f"{PARAM_SET}_lr{PARAM_LEARNING_RATE}_n{PARAM_N_STEP_UPDATE}"
    file_writer = tf.summary.create_file_writer(LOG_DIR + "/metrics")
    file_writer.set_as_default()

    # ====================================== Create C51 Agent and optimizer ======================================
    fc_layer_params = PARAM_AGENT_LAYERS
    
    categorical_q_net = categorical_q_network.CategoricalQNetwork(
        train_env_sample.observation_spec(),
        train_env_sample.action_spec(),
        num_atoms=PARAM_NUM_ATOMS,
        fc_layer_params=fc_layer_params)
    
    optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate=PARAM_LEARNING_RATE)
    
    train_step_counter = tf.Variable(initial_value=0, dtype='int64')
    
    agent = categorical_dqn_agent.CategoricalDqnAgent(
        train_env_sample.time_step_spec(),
        train_env_sample.action_spec(),
        categorical_q_network=categorical_q_net,
        optimizer=optimizer,
        min_q_value=PARAM_MIN_Q_VALUE,
        max_q_value=PARAM_MAX_Q_VALUE,
        n_step_update=PARAM_N_STEP_UPDATE,
        td_errors_loss_fn=common.element_wise_squared_loss,
        gamma=PARAM_GAMMA,
        train_step_counter=train_step_counter)
    agent.initialize()


    # ====================================== Helper for Avg Return ======================================
    
    def compute_avg_return(environment, policy, num_episodes=10):
    
        total_return = 0.0
        for _ in range(num_episodes):
    
            time_step = environment.reset()
            episode_return = 0.0
    
            while not time_step.is_last():
                action_step = policy.action(time_step)
                time_step = environment.step(action_step.action)
                episode_return += time_step.reward
            total_return += episode_return
    
        avg_return = total_return / num_episodes
        return avg_return.numpy()[0]
    
    
    random_policy = random_tf_policy.RandomTFPolicy(train_env_sample.time_step_spec(),
                                                    train_env_sample.action_spec())


    # ====================================== Collect Data ======================================
    replay_buffer = tf_uniform_replay_buffer.TFUniformReplayBuffer(
        data_spec=agent.collect_data_spec,
        batch_size=train_env_sample.batch_size,
        max_length=PARAM_REPLAY_BUFFER_CAPACITY)
    
    
    def collect_step(environment, policy):
        time_step = environment.current_time_step()
        action_step = policy.action(time_step)
        next_time_step = environment.step(action_step.action)
        traj = trajectory.from_transition(time_step, action_step, next_time_step)
        # Add trajectory to the replay buffer
        replay_buffer.add_batch(traj)
    
    
    # Collect initial data
    for _ in range(PARAM_INITIAL_COLLECT_STEPS):
        collect_step(train_env_sample, random_policy)
    
    # Dataset generates trajectories with shape [BxTx...] where
    dataset = replay_buffer.as_dataset(
        num_parallel_calls=3,
        sample_batch_size=PARAM_BATCH_SIZE,
        num_steps=PARAM_N_STEP_UPDATE + 1).prefetch(3)
    
    iterator = iter(dataset)

    # ====================================== Training Loop ======================================
    
    # (Optional) Optimize by wrapping some of the code in a graph using TF function.
    agent.train = common.function(agent.train)
    
    # Reset the train step.
    agent.train_step_counter.assign(0)
    
    # Evaluate the agent's policy once before training.
    avg_return = compute_avg_return(eval_env, agent.policy, PARAM_EVAL_EPISODES)
    returns = [avg_return]
    
    
    def get_random_train_env():
        idx = np.random.randint(len(train_py_envs))
        return tf_py_environment.TFPyEnvironment(train_py_envs[idx])
    
    
    train_env = get_random_train_env()
    iterations_per_env = 10
    
    
    for _ in range(PARAM_NUM_ITERATIONS):
        # Collect a few steps using collect_policy and save to the replay buffer.
        for _ in range(PARAM_COLLECT_STEPS_PER_ITERATION):
            collect_step(train_env, agent.collect_policy)
    
        # Sample a batch of data from the buffer and update the agent's network.
        experience, unused_info = next(iterator)
        train_loss = agent.train(experience)
    
        step = agent.train_step_counter.numpy()
    
        # Log information
        if step % PARAM_LOG_INTERVAL == 0:
            print('step = {0}: loss = {1}'.format(step, train_loss.loss))
            #tf.summary.scalar('loss2', data=train_loss.loss, step=int64(step))
    
    
        # Evaluate agent
        if step % PARAM_EVAL_INTERVAL == 0:
            avg_return = compute_avg_return(
                eval_env, agent.policy, PARAM_EVAL_EPISODES)
            print('step = {0}: Average Return = {1:.2f}'.format(
                step, avg_return))
            returns.append(avg_return)
            tf.summary.scalar('average return', data=avg_return, step=step)
    
        # Change training env
        if step % iterations_per_env == 0:
            train_env = get_random_train_env()

    print(f"Finished execution: {PARAM_SET} {PARAM_LEARNING_RATE}")'''
# Out:
# 'for VARIATION in VARIATIONS:\n\n    PARAM_SET, PARAM_AGENT_LAYERS, PARAM_LEARNING_RATE, PARAM_N_STEP_UPDATE = VARIATION\n    \n    # Create logging utilities\n    LOG_DIR = "logs/scalars/" + f"{PARAM_SET}_lr{PARAM_LEARNING_RATE}_n{PARAM_N_STEP_UPDATE}"\n    file_writer = tf.summary.create_file_writer(LOG_DIR + "/metrics")\n    file_writer.set_as_default()\n\n    # ====================================== Create C51 Agent and optimizer ======================================\n    fc_layer_params = PARAM_AGENT_LAYERS\n    \n    categorical_q_net = categorical_q_network.CategoricalQNetwork(\n        train_env_sample.observation_spec(),\n        train_env_sample.action_spec(),\n        num_atoms=PARAM_NUM_ATOMS,\n        fc_layer_params=fc_layer_params)\n    \n    optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate=PARAM_LEARNING_RATE)\n    \n    train_step_counter = tf.Variable(initial_value=0, dtype=\'int64\')\n    \n    agent = categorical_dqn_agent.CategoricalDqnAgent(\n        train_env_sample.time_step_spec(),\n        train_env_sample.action_spec(),\n        categorical_q_network=categorical_q_net,\n        optimizer=optimizer,\n        min_q_value=PARAM_MIN_Q_VALUE,\n        max_q_value=PARAM_MAX_Q_VALUE,\n        n_step_update=PARAM_N_STEP_UPDATE,\n        td_errors_loss_fn=common.element_wise_squared_loss,\n        gamma=PARAM_GAMMA,\n        train_step_counter=train_step_counter)\n    agent.initialize()\n\n\n    # ====================================== Helper for Avg Return ======================================\n    \n    def compute_avg_return(environment, policy, num_episodes=10):\n    \n        total_return = 0.0\n        for _ in range(num_episodes):\n    \n            time_step = environment.reset()\n            episode_return = 0.0\n    \n            while not time_step.is_last():\n                action_step = policy.action(time_step)\n                time_step = environment.step(action_step.action)\n                episode_return += time_step.reward\n            total_return += episode_return\n    \n        avg_return = total_return / num_episodes\n        return avg_return.numpy()[0]\n    \n    \n    random_policy = random_tf_policy.RandomTFPolicy(train_env_sample.time_step_spec(),\n                                                    train_env_sample.action_spec())\n\n\n    # ====================================== Collect Data ======================================\n    replay_buffer = tf_uniform_replay_buffer.TFUniformReplayBuffer(\n        data_spec=agent.collect_data_spec,\n        batch_size=train_env_sample.batch_size,\n        max_length=PARAM_REPLAY_BUFFER_CAPACITY)\n    \n    \n    def collect_step(environment, policy):\n        time_step = environment.current_time_step()\n        action_step = policy.action(time_step)\n        next_time_step = environment.step(action_step.action)\n        traj = trajectory.from_transition(time_step, action_step, next_time_step)\n        # Add trajectory to the replay buffer\n        replay_buffer.add_batch(traj)\n    \n    \n    # Collect initial data\n    for _ in range(PARAM_INITIAL_COLLECT_STEPS):\n        collect_step(train_env_sample, random_policy)\n    \n    # Dataset generates trajectories with shape [BxTx...] where\n    dataset = replay_buffer.as_dataset(\n        num_parallel_calls=3,\n        sample_batch_size=PARAM_BATCH_SIZE,\n        num_steps=PARAM_N_STEP_UPDATE + 1).prefetch(3)\n    \n    iterator = iter(dataset)\n\n    # ====================================== Training Loop ======================================\n    \n    # (Optional) Optimize by wrapping some of the code in a graph using TF function.\n    agent.train = common.function(agent.train)\n    \n    # Reset the train step.\n    agent.train_step_counter.assign(0)\n    \n    # Evaluate the agent\'s policy once before training.\n    avg_return = compute_avg_return(eval_env, agent.policy, PARAM_EVAL_EPISODES)\n    returns = [avg_return]\n    \n    \n    def get_random_train_env():\n         ...
